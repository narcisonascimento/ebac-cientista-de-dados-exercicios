# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
# Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.

url_rj = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r_rj = requests.get(url_rj)
print(f'Código: {r_rj.status_code}.')
# Out:
# Código: 200.

# %%
data_json_rj = r_rj.json()
print(data_json_rj['items'])
# Out:
# [{'id_pleito': 6833, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000440/2008-75', 'data_protocolo': '2008-04-11T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 15000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '18/04/2008'}, {'id_pleito': 5918, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000233/2012-05', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Corpo
# ...

# %%
df_rj = pd.DataFrame(data_json_rj['items'])
df_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       6833           Estado  Rio de Janeiro        33  RJ    None
# 1       5918           Estado  Rio de Janeiro        33  RJ    None
# 2      11961           Estado  Rio de Janeiro        33  RJ    None
# 3       9042           Estado  Rio de Janeiro        33  RJ    None
# 4      10849           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.000440/2008-75
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000233/2012-05
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001569/2009-81
# 3                                 Arquivado a pedido  17944.000891/2013-70
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001300/2012-09
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
df_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
# ...

# %%
# 2) Seu código aqui
# Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?

df_rj['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
# Construa uma nova variável que contenha o ano do status. Observe que data_status vem como tipo object no DataFrame.
# Dica: você pode usar o método .str para transformar o tipo da variável em string, em seguida um método como slice() ou split().

# Documentação Pandas - Datetime
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# Formatando a data para datetime
df_rj['data_status'] = pd.to_datetime(df_rj['data_status'], format='%d/%m/%Y')

# Criando coluna ano_status só com o ano
df_rj['ano_status'] = df_rj['data_status'].dt.year

# Dataframe com status e ano
df_status_ano = df_rj[['status', 'ano_status']]
df_status_ano
# Out:
#                                                status  ano_status
# 0                                            Deferido        2008
# 1   Encaminhado à PGFN com manifestação técnica fa...        2016
# 2   Encaminhado à PGFN com manifestação técnica fa...        2009
# 3                                  Arquivado a pedido        2014
# 4   Encaminhado à PGFN com manifestação técnica fa...        2013
# 5   Encaminhado à PGFN com manifestação técnica fa...        2012
# 6   Encaminhado à PGFN com manifestação técnica fa...        2016
# 7                                            Deferido        2012
# 8   Encaminhado à PGFN com manifestação técnica fa...        2012
# 9   Encaminhado à PGFN com manifestação técnica fa...        2008
# 10  Encaminhado à PGFN com manifestação técnica fa...        2013
# 11                                           Deferido        2002
# 12  Encaminhado à PGFN com manifestação técnica fa...        2012
# ...

# %%
# 4) Seu código aqui
# Indique a frequência de cada ano do campo construído no item (3).

df_rj['ano_status'].value_counts()
# Out:
# 2012    11
# 2009     9
# 2013     7
# 2011     6
# 2016     4
# 2014     4
# 2002     4
# 2010     3
# 2008     2
# 2006     2
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %% [markdown]
# Dataframe Exercício 1
# ---

# %%
df_rj.head()
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       6833           Estado  Rio de Janeiro        33  RJ    None
# 1       5918           Estado  Rio de Janeiro        33  RJ    None
# 2      11961           Estado  Rio de Janeiro        33  RJ    None
# 3       9042           Estado  Rio de Janeiro        33  RJ    None
# 4      10849           Estado  Rio de Janeiro        33  RJ    None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.000440/2008-75
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.000233/2012-05
# 2  Encaminhado à PGFN com manifestação técnica fa...  17944.001569/2009-81
# 3                                 Arquivado a pedido  17944.000891/2013-70
# 4  Encaminhado à PGFN com manifestação técnica fa...  17944.001300/2012-09
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %% [markdown]
# Dataframe Minas Gerais (MG)
# ---

# %%
url_mg = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'
r_mg = requests.get(url_mg)
data_json_mg = r_mg.json()
df_mg = pd.DataFrame(data_json_mg['items'])
df_mg.head()
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      20458           Estado  Minas Gerais        31  MG
# 1      13447           Estado  Minas Gerais        31  MG
# 2      22380           Estado  Minas Gerais        31  MG
# 3       5967           Estado  Minas Gerais        31  MG
# 4      13595           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0  00000.000000/2020-68                                 Arquivado a pedido
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2  00000.000000/2031-07                                 Arquivado pela STN
# 3                  None                                           Deferido
# 4                  None                                         Indeferido
#
#            num_processo        data_protocolo  \
# 0  17944.001085/2015-81  2015-11-23T02:00:00Z
# 1  19405.000002/2006-78  2009-02-02T02:00:00Z
# ...

# %%
#1) Seu código aqui
# Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado ('Estado'ou Município),
# e que devolve os dados da consulta no formato DataFrame.

# Input de dados
estado_uf = input(f'Insira a UF de interesse: ')
estado_ou_municipio = input(f'Escreva Estado ou Municipio para filtrar: ')

# Estrutura para montar o DataFrame
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=" + estado_uf + "&tipo_interessado=" + estado_ou_municipio
r = requests.get(url)
data_json = r.json()
df_escolhido = pd.DataFrame(data_json['items'])

# Definindo a função
def escolha(estado_uf, estado_ou_municipio):
    print(df_escolhido)
escolha(estado_uf, estado_ou_municipio)
print(url)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=AC&tipo_interessado=Municipio

# %%
# 2) Seu código aqui
# Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com status em
# 'Arquivado por decurso de prazo' estão registradas?

arquivado = df_mg.loc[df_mg.status == 'Arquivado por decurso de prazo']
arquivado['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
# Qual é o município da Bahia com mais solicitações deferidas?

url_ba = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'
r_ba = requests.get(url_ba)
data_json_ba = r_ba.json()
df_ba = pd.DataFrame(data_json_ba['items'])
df_ba.head()
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      18861        Município                  Coribe   2909109  BA
# 1      21643        Município                Salvador   2927408  BA
# 2      22597        Município  São Francisco do Conde   2929206  BA
# 3       5037        Município                 Aracatu   2902005  BA
# 4       5045        Município               Barreiras   2903201  BA
#
#                 num_pvl                                             status  \
# 0  00000.000000/2009-55                                           Deferido
# 1  00000.000000/2028-40  Encaminhado à PGFN com manifestação técnica fa...
# 2  00000.000000/2032-53                                           Deferido
# 3                  None                                           Deferido
# 4                  None                                          Arquivado
#
#            num_processo        data_protocolo  \
# 0  17944.000434/2015-47  2015-05-27T03:00:00Z
# ...

# %%
df_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              881 non-null    int64
#  1   tipo_interessado       881 non-null    object
#  2   interessado            881 non-null    object
#  3   cod_ibge               881 non-null    int64
#  4   uf                     881 non-null    object
#  5   num_pvl                294 non-null    object
#  6   status                 881 non-null    object
#  7   num_processo           763 non-null    object
#  8   data_protocolo         763 non-null    object
#  9   tipo_operacao          881 non-null    object
#  10  finalidade             881 non-null    object
#  11  tipo_credor            881 non-null    object
#  12  credor                 881 non-null    object
#  13  moeda                  881 non-null    object
# ...

# %%
#arquivado = df_mg.loc[df_mg.status == 'Arquivado por decurso de prazo']

ba_sol_deferidas = df_ba['interessado'].loc[df_ba.status == 'Deferido']
# ba_sol_deferidas
ba_sol_deferidas.value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  9
#                           ..
# Esplanada                  1
# Banzaê                     1
# Encruzilhada               1
# Salinas da Margarida       1
# Feira da Mata              1
# Name: interessado, Length: 175, dtype: int64

# %%
# 4) Seu código aqui
# Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

url_ba_estado = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
r_ba_estado = requests.get(url_ba_estado)
data_json_ba_estado = r_ba_estado.json()
df_ba_estado = pd.DataFrame(data_json_ba_estado['items'])
df_ba_estado.head()
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      18583           Estado       Bahia        29  BA                  None
# 1      18550           Estado       Bahia        29  BA                  None
# 2      18495           Estado       Bahia        29  BA                  None
# 3      19016           Estado       Bahia        29  BA  00000.000000/2009-87
# 4      18591           Estado       Bahia        29  BA                  None
#
#                                               status          num_processo  \
# 0                                           Deferido  19407.000057/2002-34
# 1                                           Deferido  19407.000048/2006-77
# 2                                           Deferido  19407.000035/2002-74
# 3  Encaminhado à PGFN com manifestação técnica fa...  17944.000485/2015-79
# 4                                           Deferido  19407.000059/2002-23
#
# ...

# %%
df_ba_estado.to_csv('./output/df_ba_estado.csv', index= False, encoding='utf-8-sig', sep=';')
