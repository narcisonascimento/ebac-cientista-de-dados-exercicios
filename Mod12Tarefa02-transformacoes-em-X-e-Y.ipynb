# %% [markdown]
# # Regressão 01 - tarefa 02 - transformações em X e Y

# %% [markdown]
# ### 1. Melhorando o ajuste no percentual de gorjetas
#
# a. Vamos partir do modelo feito na última tarefa, o que relaciona ```tip_pct``` e ```net_bill```. Carregue a base, os pacotes e reproduza este modelo aqui.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

from seaborn import load_dataset

# %matplotlib inline

# %%
# Carregando os dados e criando as variáveis
tips = sns.load_dataset(('tips'))
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips['net_bill'] = tips['total_bill'] - tips['tip']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct  net_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204     15.98
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244      8.68
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886     17.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494     20.37
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069     20.98

# %%
# Modelo tip_pct x net_bill
reg_tip_pct = smf.ols('tip_pct ~ net_bill', data=tips).fit()
print(reg_tip_pct.summary())

sns.regplot(
    data=tips[tips['tip_pct']<.5],
    x='net_bill',
    y='tip_pct'
)

plt.xlim(left = 0)
plt.ylim(bottom = 0)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Thu, 20 Oct 2022   Prob (F-statistic):           1.52e-06
# Time:                        16:46:02   Log-Likelihood:                 108.00
# No. Observations:                 244   AIC:                            -212.0
# Df Residuals:                     242   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3053      0.023     13.166      0.000       0.260       0.351
# net_bill      -0.0061      0.001     -4.931      0.000      -0.009      -0.004
# ==============================================================================
# Omnibus:                      468.674   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           234437.604
# Skew:                          11.104   Prob(JB):                         0.00
# Kurtosis:                     153.221   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# (0.0, 0.505398619388979)

# %% [markdown]
# ### 2. ajuste o modelo de ```tip_pct``` em função do logaritmo de ```net_bill```.

# %%
reg_tip_pct = smf.ols('tip_pct ~ np.log(net_bill)', data=tips).fit()
print(reg_tip_pct.summary())

tips['res'] = reg_tip_pct.resid

sns.scatterplot(
    data=tips[tips['tip_pct'] < .5],
    x='net_bill',
    y='res',
    alpha=.75
)

plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     61.16
# Date:                Thu, 20 Oct 2022   Prob (F-statistic):           1.62e-13
# Time:                        16:46:46   Log-Likelihood:                 123.81
# No. Observations:                 244   AIC:                            -243.6
# Df Residuals:                     242   BIC:                            -236.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.6181      0.054     11.444      0.000       0.512       0.724
# np.log(net_bill)    -0.1534      0.020     -7.820      0.000      -0.192      -0.115
# ==============================================================================
# Omnibus:                      440.899   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           171509.052
# Skew:                           9.850   Prob(JB):                         0.00
# Kurtosis:                     131.381   Cond. No.                         17.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.close('all')

sns.regplot(x='net_bill', y='tip_pct', data=tips[tips['tip_pct'] < .5])
plt.plot(tips['net_bill'], reg_tip_pct.fittedvalues, 'r,--')

# %%
tips['pred'] = reg_tip_pct.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0, 1]
r
# Out:
# 0.44914234088544225

# %% [markdown]
# ###  3. ajuste o modelo de ```tip_pct``` em função de um polinômio de segundo grau em ```net_bill```.

# %%
plt.close('all')

reg_tip_pct = smf.ols('tip_pct ~ np.power(net_bill, 2)', data=tips).fit()
print(reg_tip_pct.summary())

tips['res'] = reg_tip_pct.resid

sns.scatterplot(
    data=tips[tips['tip_pct'] < .5],
    x='net_bill',
    y='res',
    alpha=.75
)

plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                tip_pct   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     13.48
# Date:                Thu, 20 Oct 2022   Prob (F-statistic):           0.000297
# Time:                        16:48:01   Log-Likelihood:                 102.94
# No. Observations:                 244   AIC:                            -201.9
# Df Residuals:                     242   BIC:                            -194.9
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.2388      0.014     16.725      0.000       0.211       0.267
# np.power(net_bill, 2)    -0.0001   2.89e-05     -3.672      0.000      -0.000   -4.91e-05
# ==============================================================================
# Omnibus:                      471.934   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           242314.902
# Skew:                          11.261   Prob(JB):                         0.00
# Kurtosis:                     155.732   Cond. No.                         692.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.close('all')

sns.regplot(x='net_bill', y='tip_pct', data=tips[tips['tip_pct'] < .5])
plt.plot(tips['net_bill'], reg_tip_pct.fittedvalues, 'r,--')

# %%
tips['pred'] = reg_tip_pct.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0, 1]
r
# Out:
# 0.22971434805042354

# %% [markdown]
# ###  4. ajuste um modelo no log do ```tip_pct``` em função de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```

# %%
plt.close('all')

# ajustando uma função logaritmica de y

reg_tip_pct = smf.ols('np.log(tip_pct + .1) ~ net_bill', data=tips).fit()
print(reg_tip_pct.summary())

tips['res'] = reg_tip_pct.resid

sns.scatterplot(
    data=tips[tips['tip_pct'] < .5],
    x='net_bill',
    y='res',
    alpha=.75
)

plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     np.log(tip_pct + .1)   R-squared:                       0.213
# Model:                              OLS   Adj. R-squared:                  0.209
# Method:                   Least Squares   F-statistic:                     65.35
# Date:                  Thu, 20 Oct 2022   Prob (F-statistic):           3.00e-14
# Time:                          16:49:23   Log-Likelihood:                -7.1139
# No. Observations:                   244   AIC:                             18.23
# Df Residuals:                       242   BIC:                             25.22
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9782      0.037    -26.320      0.000      -1.051      -0.905
# net_bill      -0.0162      0.002     -8.084      0.000      -0.020      -0.012
# ==============================================================================
# Omnibus:                      150.700   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2287.003
# Skew:                           2.109   Prob(JB):                         0.00
# Kurtosis:                      17.393   Cond. No.                         43.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.close('all')

sns.regplot(x='net_bill', y='tip_pct', data=tips[tips['tip_pct'] < .5])
plt.plot(tips['net_bill'], reg_tip_pct.fittedvalues, 'r,--')

# %%
tips['pred'] = reg_tip_pct.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0, 1]
r
# Out:
# 0.3021437558623867

# %% [markdown]
# ###  5. ajuste um modelo no log do ```tip_pct``` em função do log de ```net_bill```. Calcule o $R^2$ também em ```tip_pct```.

# %%
plt.close('all')

# ajustando log em Y e log em X

reg_tip_pct = smf.ols('np.log(tip_pct + .1) ~ np.log(net_bill + .1)', data=tips).fit()
print(reg_tip_pct.summary())

tips['res'] = reg_tip_pct.resid

sns.scatterplot(
    data=tips[tips['tip_pct'] < .5],
    x='net_bill',
    y='res',
    alpha=.75
)

plt.axhline(y=0, color='r', linestyle='--')
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     np.log(tip_pct + .1)   R-squared:                       0.295
# Model:                              OLS   Adj. R-squared:                  0.292
# Method:                   Least Squares   F-statistic:                     101.1
# Date:                  Thu, 20 Oct 2022   Prob (F-statistic):           4.21e-20
# Time:                          16:50:02   Log-Likelihood:                 6.3140
# No. Observations:                   244   AIC:                            -8.628
# Df Residuals:                       242   BIC:                            -1.634
# Df Model:                             1
# Covariance Type:              nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.3736      0.088     -4.227      0.000      -0.548      -0.199
# np.log(net_bill + .1)    -0.3221      0.032    -10.056      0.000      -0.385      -0.259
# ==============================================================================
# Omnibus:                       89.857   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              565.505
# Skew:                           1.301   Prob(JB):                    1.59e-123
# Kurtosis:                       9.990   Cond. No.                         18.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.close('all')

sns.regplot(x='net_bill', y='tip_pct', data=tips[tips['tip_pct'] < .5])
plt.plot(tips['net_bill'], reg_tip_pct.fittedvalues, 'r,--')

# %%
tips['pred'] = reg_tip_pct.fittedvalues

r = tips[['pred', 'tip_pct']].corr().iloc[0, 1]
r
# Out:
# 0.44645109639929226

# %% [markdown]
# ###  6. qual modelo resultou no melhor ajuste?

# %% [markdown]
# Se todas as execuções estiverem corretas, o melhor resultado foi o log em Y e log em X.
