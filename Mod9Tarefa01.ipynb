# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
exercicio_1 = sinasc_raw[['munResNome', 'IDADEMAE', 'IDADEPAI']]
# exercicio_1.pivot_table(index='munResNome', aggfunc='mean')
exercicio_1.groupby(['munResNome']).mean()
# Out:
#                             IDADEMAE   IDADEPAI
# munResNome
# Alta Floresta D'Oeste      25.991826  29.548701
# Alto Alegre dos Parecis    24.844156  29.179104
# Alto Paraíso               24.960177  28.833333
# Alvorada D'Oeste           25.770732  30.757282
# Ariquemes                  25.607866  32.466667
# Buritis                    25.559177  30.812500
# Cabixi                     26.037500  34.333333
# Cacaulândia                25.546667  36.333333
# Cacoal                     26.890102  30.931854
# Campo Novo de Rondônia     24.825301  30.500000
# Candeias do Jamari         25.243323  29.894737
# Castanheiras               27.281250  30.392857
# Cerejeiras                 27.240506  31.652778
# Chupinguaia                25.333333  29.629630
# Colorado do Oeste          27.602804  34.354839
# Corumbiara                 24.716535  32.470588
# Costa Marques              24.412017  30.613636
# Cujubim                    24.482927  31.400000
# ...

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
exercicio_2 = sinasc_raw[sinasc_raw['DTNASC'] == '2019-04-22'].groupby(['DTNASC', 'SEXO', 'ESCMAE'])['PESO'].mean().to_frame()
exercicio_2
# Out:
#                                              PESO
# DTNASC     SEXO      ESCMAE
# 2019-04-22 Feminino  1 a 3 anos       3302.500000
#                      12 anos ou mais  3037.400000
#                      4 a 7 anos       3140.333333
#                      8 a 11 anos      3256.363636
#            Masculino 12 anos ou mais  3340.625000
#                      4 a 7 anos       3545.000000
#                      8 a 11 anos      3363.620690

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
# contando bebes por município
exercicio_3 = sinasc_raw[sinasc_raw['QTDFILVIVO'] == 0].groupby(['munResNome'])['QTDFILVIVO'].count().sort_values(ascending=True).to_frame()
exercicio_3
# Out:
#                            QTDFILVIVO
# munResNome
# Parecis                             8
# Primavera de Rondônia              12
# Castanheiras                       13
# Rio Crespo                         17
# Pimenteiras do Oeste               17
# São Felipe D'Oeste                 24
# Teixeirópolis                      26
# Ministro Andreazza                 28
# Campo Novo de Rondônia             29
# Cacaulândia                        29
# Itapuã do Oeste                    30
# Espigão D'Oeste                    30
# Vale do Anari                      32
# Santa Luzia D'Oeste                39
# Novo Horizonte do Oeste            39
# Theobroma                          39
# Vale do Paraíso                    41
# Cabixi                             41
# Buritis                            45
# Nova União                         45
# Governador Jorge Teixeira          46
# Corumbiara                         53
# Mirante da Serra                   59
# ...

# %%
# min, max, e media da idade do pai e mae do município com menor número de nascimentos 
exercicio_3_idades = sinasc_raw[sinasc_raw['munResNome'] == 'Parecis'].groupby(['munResNome']).agg({'IDADEMAE': ['mean', 'min', 'max'], 'IDADEPAI': ['mean', 'min', 'max']})
exercicio_3_idades
# Out:
#              IDADEMAE           IDADEPAI
#                  mean min max       mean   min   max
# munResNome
# Parecis     26.454545  16  41  32.473684  18.0  61.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %%
# município com maior número de nascimentos no mês de março

sinasc_raw['MES'] = pd.DatetimeIndex(sinasc_raw['DTNASC']).month
exercicio_4 = sinasc_raw[sinasc_raw['MES'] == 3].groupby(['MES', 'munResNome'])['QTDFILVIVO'].count().sort_values(ascending=False).to_frame()
exercicio_4
# Out:
#                                QTDFILVIVO
# MES munResNome
# 3   Porto Velho                       627
#     Ji-Paraná                         187
#     Vilhena                           147
#     Ariquemes                         139
#     Cacoal                            132
#     Jaru                               78
#     Guajará-Mirim                      73
#     Rolim de Moura                     69
#     Ouro Preto do Oeste                67
#     Pimenta Bueno                      61
#     Nova Mamoré                        50
#     Espigão D'Oeste                    44
#     Machadinho D'Oeste                 44
#     São Miguel do Guaporé              40
#     Buritis                            38
#     São Francisco do Guaporé           31
#     Alta Floresta D'Oeste              31
#     Presidente Médici                  29
#     Candeias do Jamari                 28
#     Costa Marques                      24
#     Alto Paraíso                       21
# ...

# %%
# qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
exercicio_4_quantidade_filhos = sinasc_raw[sinasc_raw['munResNome'] == 'Porto Velho'].groupby(['munResNome'])['QTDFILVIVO'].describe()
exercicio_4_quantidade_filhos
# Out:
#               count      mean      std  min  25%  50%  75%   max
# munResNome
# Porto Velho  7319.0  1.167236  1.22264  0.0  0.0  1.0  2.0  12.0

# %%
# qual a idade media, maxima, minima dos pais nesse municipio?
# exercicio_4_idades = sinasc_raw[(sinasc_raw['munResNome'] == 'Porto Velho') & (sinasc_raw['MES'] == 3)].groupby(['MES', 'munResNome']).agg({'IDADEMAE': ['mean', 'min', 'max'], 'IDADEPAI': ['mean', 'min', 'max']})
exercicio_4_idades = sinasc_raw[(sinasc_raw['munResNome'] == 'Porto Velho')].groupby(['munResNome']).agg({'IDADEMAE': ['mean', 'min', 'max'], 'IDADEPAI': ['mean', 'min', 'max']})
exercicio_4_idades
# Out:
#              IDADEMAE           IDADEPAI
#                  mean min max       mean   min   max
# munResNome
# Porto Velho  26.31267  12  47  32.352679  16.0  65.0

# %% [markdown]
# Insight 1
# ---
# Quanto maior o nível de escolaridade da mãe, maior é a quantidade de consultas.

# %%
sinasc_raw.groupby(['ESCMAE'])['CONSULTAS'].count().sort_values().plot(figsize=[15,5])
# Out:
# <AxesSubplot: xlabel='ESCMAE'>

# %%
sns.catplot(data = sinasc_raw,
            x = 'ESCMAE',
            y = 'CONSULTAS',
            # hue = "time",
            kind = 'bar'
            )

# %% [markdown]
# Insight 2
# ---
# Maior número de filhos mortos é no período de gestação entre 22 a 27 semanas e são os bebês do sexo feminino

# %%
sns.catplot(
    data = sinasc_raw,
    kind = 'bar',
    x = 'GESTACAO',
    y = "QTDFILMORT",
    hue = 'SEXO',
    palette = 'colorblind',
    alpha = .6,
    height = 6
)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '37 a 41 semanas'),
#   Text(1, 0, '42 semanas e mais'),
#   Text(2, 0, '32 a 36 semanas'),
#   Text(3, 0, '22 a 27 semanas'),
#   Text(4, 0, '28 a 31 semanas'),
#   Text(5, 0, 'Menos de 22 semanas')])

# %% [markdown]
# Insight 3
# ---
# Maior número de partos é Cesário com maior número de bebês do sexo masculino.

# %%
sns.catplot(data = sinasc_raw,
            x = 'PARTO',
            hue = 'SEXO',
            kind = 'count'
            )
