# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %%
import pandas as pd
import numpy as np
import plotly.express as px

from pandas_datareader import data as web

from plotly import graph_objects

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
# %%time

# Amazon, Lenovo e Apple
ativos = ['AMZN', '0992.HK', 'AAPL']
dt_ini = '01/01/2019'

yf = web.get_data_yahoo(ativos, start=dt_ini)
yf.head()
# Out:
# CPU times: total: 219 ms
# Wall time: 3.52 s
# Attributes  Adj Close                           Close                     \
# Symbols          AMZN   0992.HK       AAPL       AMZN 0992.HK       AAPL
# Date
# 2019-01-02  76.956497  4.259930  38.105141  76.956497    5.13  39.480000
# 2019-01-03  75.014000  4.251625  34.309589  75.014000    5.12  35.547501
# 2019-01-04  78.769501  4.318057  35.774235  78.769501    5.20  37.064999
# 2019-01-07  81.475502  4.193497  35.694611  81.475502    5.05  36.982498
# 2019-01-08  82.829002  4.259930  36.375057  82.829002    5.13  37.687500
#
# Attributes       High                           Low                     \
# Symbols          AMZN 0992.HK       AAPL       AMZN 0992.HK       AAPL
# Date
# 2019-01-02  77.667999    5.36  39.712502  73.046501    5.10  38.557499
# 2019-01-03  76.900002    5.25  36.430000  74.855499    5.09  35.500000
# 2019-01-04  79.699997    5.25  37.137501  75.915497    5.08  35.950001
# 2019-01-07  81.727997    5.28  37.207500  79.459503    5.05  36.474998
# 2019-01-08  83.830498    5.17  37.955002  80.830498    5.05  37.130001
#
# Attributes       Open                          Volume
# Symbols          AMZN 0992.HK       AAPL         AMZN     0992.HK         AAPL
# Date
# 2019-01-02  73.260002    5.36  38.722500  159662000.0  17150376.0  148158800.0
# 2019-01-03  76.000504    5.10  35.994999  139512000.0  24350994.0  365248800.0
# 2019-01-04  76.500000    5.08  36.132500  183652000.0  15722442.0  234428400.0
# 2019-01-07  80.115501    5.28  37.174999  159864000.0  43699496.0  219111200.0
# 2019-01-08  83.234497    5.10  37.389999  177628000.0  26181663.0  164101200.0

# %%
yf.to_csv('./input/data_yahoo_finance.csv')

# %%
yf.shape
# Out:
# (998, 18)

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %%
amplitudade = yf['High'] - yf['Low']
amplitudade
# Out:
# Symbols         AMZN  0992.HK      AAPL
# Date
# 2019-01-02  4.621498     0.26  1.155003
# 2019-01-03  2.044502     0.16  0.930000
# 2019-01-04  3.784500     0.17  1.187500
# 2019-01-07  2.268494     0.23  0.732502
# 2019-01-08  3.000000     0.12  0.825001
# ...              ...      ...       ...
# 2022-11-04  4.400002     0.43  8.289993
# 2022-11-07  3.059998     0.48  3.479996
# 2022-11-08  3.489998     0.17  3.939987
# 2022-11-09  3.610001     0.16  3.960007
# 2022-11-10  7.040001     0.21  3.300003
#
# [998 rows x 3 columns]

# %%
amplitudade_vertical = yf['Adj Close'].stack().reset_index()
amplitudade_vertical.columns = ['data', 'ativo', 'valor']

amplitudade_vertical.head()
# Out:
#         data    ativo      valor
# 0 2019-01-02     AMZN  76.956497
# 1 2019-01-02  0992.HK   4.259930
# 2 2019-01-02     AAPL  38.105141
# 3 2019-01-03     AMZN  75.014000
# 4 2019-01-03  0992.HK   4.251625

# %%
fig = px.line(amplitudade_vertical, x='data', y='valor', color='ativo', template='plotly_white')
fig.show()

# %% [markdown]
# #### Resposta:
#
# Os ativos Amazon e Apple apresentam maior volatilidade comparados ao da Lenovo.
