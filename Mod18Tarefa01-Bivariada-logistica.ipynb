# %% [markdown]
# # Regressão Logística I
# ## Tarefa I
#
# Neste exercício vamos trabalhar com a base "Heart Disease Data Set" disponível no site do [UCI](https://archive.ics.uci.edu/ml/datasets/heart+disease).
#
# Temos 303 indivíduos e vamos utilizar 13 variáveis disponíveis para prever a presença de doença cardíaca na variável ```num```(a 14$^a$ variável).
#
# A descrição das variáveis está recortada abaixo:
# - age: idade do paciente em anos
# - sex: sexo (1 = male; 0 = female)
# - cp: tipo de dor no peito
#   - 1: angina típica
#   - 2: angina atípica
#   - 3: dor não-angina
#   - 4: assintomático
# - trestbps: pressão sanguínea em repouso (em mm Hg na admissão ao hospital
# - chol: colesterol sérico em mg/dl
# - fbs: (açúcar no sangue em jejum > 120 mg/dl) (1 = True; 0 = False)
# - restecg: resultados eletrocardiográficos em repouso
#   - 0: normal
#   - 1: tendo anormalidade da onda ST-T (Inversões de onda T e / ou ST com elevação ou depressão de > 0.05 mV)
#   - 2: mostrando hipertrofia ventricular esquerda provável ou definitiva pelos critérios de Estes
# - thalach: frequência cardíaca máxima alcançada
# - exang: angina induzida por exercício(1 = sim; 0 = não)
# - oldpeak = Depressão de ST induzida por exercício em relação ao repouso
# - slope: Depressão de ST induzida por exercício em relação ao repouso
#   - 1: inclinação ascendente
#   - 2: estável
#   - 3: inclinação descendente
# - ca: número de vasos principais (0-3) coloridos por fluorosopia
# - thal: 3 = normal; 6 = defeito corrigido; 7 = defeito reversível
# - num: diagnóstico de doença cardíaga (status de doença angiográfica)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import statsmodels.formula.api as smf

# %matplotlib inline

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'

df = pd.read_csv(url,
                 names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
                        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'])
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df['flag_doente'] = (df['num'] != 0).astype('int64')
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num  flag_doente
# 0      3.0  0.0  6.0    0            0
# 1      2.0  3.0  3.0    2            1
# 2      2.0  2.0  7.0    1            1
# 3      3.0  0.0  3.0    0            0
# 4      1.0  0.0  3.0    0            0
# ..     ...  ...  ...  ...          ...
# 298    2.0  0.0  7.0    1            1
# 299    2.0  2.0  7.0    2            1
# 300    2.0  1.0  7.0    3            1
# 301    2.0  1.0  3.0    1            1
# 302    1.0    ?  3.0    0            0
#
# [303 rows x 15 columns]

# %% [markdown]
# 1. Monte uma bivariada para a variável ```sex``` com as seguintes estatísticas:
#
# - Número de *saudáveis*
# - Número de *doentes*
# - Total
# - Quantidade média de doentes
# - *Odds*
# - *Odds ratio* (Use o total como referência)
# - Logito (LOG(*Odds*))
# - O LOG do *Odds ratio* (com o total como referência) é chamado de *Weight of Evidence* (WOE). Calcule-o.

# %%
# alterando 0/1 para dados categóricos
df['sex'].replace({0: 'feminino', 1: 'masculino'}, inplace=True)
df['flag_doente'].replace({0: 'saudavel', 1: 'doente'}, inplace=True)

# %%
# crosstab sex e flag_doentes com total
tab_sex = pd.crosstab(df['sex'], df['flag_doente'], margins=True)

# quantidae media de doentes
tab_sex['media_doentes'] = tab_sex['doente'] / tab_sex['All']

# odds
tab_sex['odds_doentes'] = tab_sex['media_doentes'] / (1 - tab_sex['media_doentes'])

# odds ratio
tab_sex['odds_ratio'] = tab_sex['odds_doentes'] / tab_sex.loc['All', 'odds_doentes']

# logito
tab_sex['logito_doentes'] = np.log(tab_sex['odds_doentes'])

# woe (log odds ratio)
tab_sex['woe'] = np.log(tab_sex['odds_ratio'])

tab_sex
# Out:
# flag_doente  doente  saudavel  All  media_doentes  odds_doentes  odds_ratio  \
# sex
# feminino         25        72   97       0.257732      0.347222    0.409672
# masculino       114        92  206       0.553398      1.239130    1.461996
# All             139       164  303       0.458746      0.847561    1.000000
#
# flag_doente  logito_doentes       woe
# sex
# feminino          -1.057790 -0.892398
# masculino          0.214410  0.379802
# All               -0.165392  0.000000

# %% [markdown]
# 2. Monte uma bivariada para a variável ```age``` com as seguintes estatísticas:
# - Categorize a variável em 5 grupos
# - Calcule as mesmas quantidades calculadas no execício anterior
# - Calcule também o valor médio da variável ```age```

# %%
# verificando a variável age
print(df.age.min())
print(df.age.max())
print(df.age.mean())
# Out:
# 29.0
# 77.0
# 54.43894389438944

# %%
# categorizando em grupos
bins = [28, 38, 48, 58, 68, 78]
labels = ['28 a 37 anos',
          '38 a 47 anos',
          '48 a 57 anos',
          '58 a 67 anos',
          '68 a 77 anos']

df['age_grupo'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)
df.head()
# Out:
#     age        sex   cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0  63.0  masculino  1.0     145.0  233.0  1.0      2.0    150.0    0.0
# 1  67.0  masculino  4.0     160.0  286.0  0.0      2.0    108.0    1.0
# 2  67.0  masculino  4.0     120.0  229.0  0.0      2.0    129.0    1.0
# 3  37.0  masculino  3.0     130.0  250.0  0.0      0.0    187.0    0.0
# 4  41.0   feminino  2.0     130.0  204.0  0.0      2.0    172.0    0.0
#
#    oldpeak  slope   ca thal  num flag_doente     age_grupo
# 0      2.3    3.0  0.0  6.0    0    saudavel  58 a 67 anos
# 1      1.5    2.0  3.0  3.0    2      doente  58 a 67 anos
# 2      2.6    2.0  2.0  7.0    1      doente  58 a 67 anos
# 3      3.5    3.0  0.0  3.0    0    saudavel  28 a 37 anos
# 4      1.4    1.0  0.0  3.0    0    saudavel  38 a 47 anos

# %%
# crosstab age e flag_doentes com total
tab_age = pd.crosstab(df['age_grupo'], df['flag_doente'], margins=True)

# quantidae media de doentes
tab_age['media_doentes'] = tab_age['doente'] / tab_age['All']

# odds
tab_age['odds_doentes'] = tab_age['media_doentes'] / (1 - tab_age['media_doentes'])

# odds ratio
tab_age['odds_ratio'] = tab_age['odds_doentes'] / tab_age.loc['All', 'odds_doentes']

# logito
tab_age['logito_doentes'] = np.log(tab_age['odds_doentes'])

# woe (log odds ratio)
tab_age['woe'] = np.log(tab_age['odds_ratio'])

tab_age
# Out:
# flag_doente   doente  saudavel  All  media_doentes  odds_doentes  odds_ratio  \
# age_grupo
# 28 a 37 anos       2         7    9       0.222222      0.285714    0.337102
# 38 a 47 anos      19        47   66       0.287879      0.404255    0.476963
# 48 a 57 anos      44        60  104       0.423077      0.733333    0.865228
# 58 a 67 anos      67        40  107       0.626168      1.675000    1.976259
# 68 a 77 anos       7        10   17       0.411765      0.700000    0.825899
# All              139       164  303       0.458746      0.847561    1.000000
#
# flag_doente   logito_doentes       woe
# age_grupo
# 28 a 37 anos       -1.252763 -1.087370
# 38 a 47 anos       -0.905709 -0.740316
# 48 a 57 anos       -0.310155 -0.144762
# 58 a 67 anos        0.515813  0.681206
# 68 a 77 anos       -0.356675 -0.191282
# All                -0.165392  0.000000

# %% [markdown]
# 3. Visualize a informação da bivariada construída acima através de um gráfico da sua escolha.

# %%
(tab_age[['doente', 'saudavel']]
 .drop('All')
 .plot.bar(rot=0, figsize=(10, 5), zorder=2))
# Out:
# <AxesSubplot:xlabel='age_grupo'>

# %%
(tab_age[['media_doentes', 'odds_doentes', 'odds_ratio', 'logito_doentes', 'woe']]
 .drop('All')
 .plot.bar(rot=0, figsize=(10, 5), zorder=2)
 .grid(zorder=1, color='grey', axis='y'))
